# %%
import numpy as np

def read_matrix(rows, cols):
    matrix = []
    print(f"Enter the elements of the matrix ({rows}x{cols}):")
    for _ in range(rows):
        row = [int(x) for x in input().split()]
        if len(row) != cols:
            raise ValueError("Invalid number of columns!")
        matrix.append(row)
    return matrix

def print_matrix(matrix):
    for row in matrix:
        print(" ".join(str(x) for x in row))

# Read matrix dimensions from the user
rows = int(input("Enter the number of rows: "))
cols = int(input("Enter the number of columns: "))

# Read matrices from the user
matrix1 = read_matrix(rows, cols)
matrix2 = read_matrix(rows, cols)

# Perform matrix operations
add_result = np.add(matrix1,matrix2)
sub_result = np.subtract(matrix1, matrix2)
mul_result = np.dot(matrix1, matrix2)
transpose_result = np.transpose(matrix1)
inverse_result = np.linalg.inv(matrix1)

# Print the results
print("\nMatrix Addition:")
print_matrix(add_result)

print("\nMatrix Subtraction:")
print_matrix(sub_result)

print("\nMatrix Multiplication:")
print_matrix(mul_result)

print("\nMatrix Transpose:")
print_matrix(transpose_result)

print("\nMatrix Inverse:")
print_matrix(inverse_result)
# Out:
# Enter the number of rows: 3
# Enter the number of columns: 3
# Enter the elements of the matrix (3x3):
# 2 3 4
# 5 3  8
# 6 5 9
# Enter the elements of the matrix (3x3):
# 1 5 6
# 6 7 5
# 9 4  8
#
# Matrix Addition:
# 3 8 10
# 11 10 13
# 15 9 17
#
# Matrix Subtraction:
# 1 -2 -2
# -1 -4 3
# -3 1 1
#
# Matrix Multiplication:
# 56 47 59
# 95 78 109
# 117 101 133
#
# Matrix Transpose:
# 2 5 6
# 3 3 5
# 4 8 9
#
# Matrix Inverse:
# -1.1818181818181812 -0.6363636363636365 1.0909090909090908
# 0.27272727272727293 -0.5454545454545454 0.3636363636363635
# 0.636363636363636 0.7272727272727273 -0.818181818181818
